# %%
import json
import orjson
import glob
from pathlib import Path, WindowsPath

import pandas as pd
import numpy as np

import re

# %%
# User arguments

pattern = r'mask_tf(\d+)_apoc_cell(\d+)\.json'
port = 5019
input_path = r"H:\PROJECTS-03\Pablo\oscillating\Laurel_project\ppp009"
output_path = r"H:\PROJECTS-03\Pablo\oscillating\Laurel_project\analysis\raw_signals_ppp009"
nan_threshold = 0.8
var_cri = 100
current_socket = 'localhost:8889'
channel = 1
df = pd.DataFrame()

# %%
# Ordering functions

def ordering_function_tf(path):
    """Give the timeframe contained in the name of the json file as an integer.
    Use to sort metadata files"""
    
    pattern = r'mask_tf(\d+)_apoc_cell(\d+)\.json'
    match = re.match(pattern, path.name)
    return int(match.group(1))

def ordering_function_cell(path):
    """Give the cell number contained in the name of the json file as an integer.
    Use to sort metadata files"""

    pattern = r'mask_tf(\d+)_apoc_cell(\d+)\.json'
    match = re.match(pattern, path.name)
    return int(match.group(2))

def process_subdirectory(subdirectory_path, pattern=pattern, df=df, channel=channel):
    json_files = list(subdirectory_path.glob('mask_tf*_apoc_cell*.json'))
    json_files.sort(key=lambda x: (ordering_function_cell(x), ordering_function_tf(x)))
    cells = {re.match(pattern, file.name).group(2) for file in json_files} # Cell numbers as in the metadata file names

    # Check whether cells is emptyy or metadata has been found, if so populate df with average intenstiy
    if cells:
        for cell in cells:
            print(f'Recording cells {subdirectory.name}+{cell}')
            json_cell = [json_file for json_file in json_files if 'apoc_cell'+cell in json_file.stem]
            tfs = [int((re.match(pattern,json_file.name)).group(1)) for json_file in json_cell]
            tfs.sort()
            for (tf, json_file) in zip(tfs, json_cell):
                with json_file.open('rb') as file:
                    data_dict = orjson.loads(file.read())
                    npixels = data_dict.get('npixels')
                    intensity = data_dict.get('intensity')[channel] if 'intensity' in data_dict and len(data_dict['intensity']) > 1 else None
                    column_name = subdirectory_path.name+'_'+cell
                    df.at[tf, column_name] = intensity/npixels
    else:
        print(f'No cell metadata in {subdirectory_path.name}')
    
    return df.sort_index()
    
    # except AttributeError as e:
    #     print(f'No cell metadata in {subdirectory_path.name}: {e}')
    #     pass

# %%
root_folder = Path(input_path).resolve()

if not root_folder.exists():
    raise FileNotFoundError(f"Root folder does not exist: {root_folder}")

subdirectories = [p.resolve() for p in root_folder.glob('*/') if p.is_dir()]

# %%
subdirectories

# %%
for subdirectory in subdirectories:
    df = process_subdirectory(subdirectory, df=df)

# Filter traces with nan_values defined by nan_threshold

# %%
df_cleaned = df.drop(columns=df.columns[df.isna().sum() > nan_threshold*len(df)])

# Filter values with variance criterion defined in var_cri

variances = df_cleaned.var()
df_cleaned = df_cleaned.loc[:, variances > var_cri]

# %%
# Port may have to be changed if the other one is currently in used
df_cleaned = pd.read_csv(Path(output_path).as_posix(),index_col=0)
port=5019

# %%
from bokeh.io import output_notebook, show, push_notebook
from bokeh.layouts import column, row
from bokeh.models import Button, ColumnDataSource, CustomJS
from bokeh.plotting import figure, curdoc
from bokeh.application.handlers import FunctionHandler
from bokeh.application import Application
from bokeh.server.server import Server
from tornado.ioloop import IOLoop
import asyncio


global valid_signals

def modify_doc(doc):
    # Initialize selected_plots as a ColumnDataSource
    selected_plots_source = ColumnDataSource(data=dict(selected_plots=[]))

    # Function to get selected plots in Python
    def get_selected_plots():
        return selected_plots_source.data['selected_plots']

    # Function to create plots and buttons layout
    def create_plots_layout():
        plots = []
        buttons = []
        x_vals = list(range(len(df_cleaned)))
        for col in df_cleaned.columns:
            if col not in get_selected_plots():
                source = ColumnDataSource(data={col: df_cleaned[col], 'x': range(len(df_cleaned))})
                p = figure(width=250, height=250, title=col, x_range=(x_vals[0], x_vals[-1])) # Figures in full range of dataFrame
                # p = figure(width=250, height=250, title=col) # Figures up to last valid value
                r = p.line('x', col, source=source, line_width=2, color='navy', alpha=0.8)

                button = Button(label=col, width=60, button_type="success")

                def create_button_callback(plot, column_name, btn):
                    def callback():
                        selected_plots = selected_plots_source.data['selected_plots']
                        if column_name in selected_plots:
                            plot.background_fill_color = 'white'
                            selected_plots.remove(column_name)
                            btn.button_type = 'success'
                        else:
                            plot.background_fill_color = 'rgba(255, 0, 0, 0.1)'
                            selected_plots.append(column_name)
                            btn.button_type = 'danger'
                        selected_plots_source.data = {'selected_plots': selected_plots}  # Update the data source
                        global valid_signals
                        valid_signals = df_cleaned.drop(columns=selected_plots_source.data['selected_plots']).columns
                        # push_notebook()  # Ensure updates are reflected in the notebook
                    return callback

                button.on_click(create_button_callback(p, col, button))

                plots.append(p)
                buttons.append(button)

        # Organize layout
        plot_rows = []
        for i in range(0, len(plots), 5):
            plot_row = plots[i:i+5]
            button_row = buttons[i:i+5]
            plot_rows.append(row(*plot_row, column(*button_row)))

        layout = column(*plot_rows)
        return layout

    # Create the initial layout
    layout = create_plots_layout()

    # Button to print excluded plots
    print_button = Button(label="Print list of excluded plots", width=200, button_type="primary")
    def print_selected_plots():
        print(get_selected_plots())
        # push_notebook()  # Ensure notebook updates
    print_button.on_click(print_selected_plots)

    # Button to rerender without selected plots
    rerender_button = Button(label="Exclude selected plots", width=200, button_type="warning")
    def rerender_plots():
        new_layout = create_plots_layout()
        doc.clear()  # Clear the current document
        doc.add_root(column(new_layout, print_button, rerender_button))
        # push_notebook()
    rerender_button.on_click(rerender_plots)

    # Add the layout and buttons to the current document
    doc.add_root(column(layout, print_button, rerender_button))

# Create the application
app = Application(FunctionHandler(modify_doc))


# Display app
# show(app, notebook_handle=True) - Carefull to push notebook

# Or do it through a server

#  Start the Bokeh server
# server = Server({'/': modify_doc}, port=4996)
#  server.start()

# def show_app():
#     server.io_loop.add_callback(server.show, "/")
#     server.io_loop.start()

# show_app()

#########################
# Integrate with the current Jupyter server -- To be checked
server = Server({'/': modify_doc}, port=port, io_loop=IOLoop.current(), allow_websocket_origin=[current_socket, "localhost:"+str(port)])

async def show_app():
    server.io_loop.add_callback(server.show, "/")
    await server.io_loop.start()

# Integrate with the Jupyter notebook event loop
loop = asyncio.get_event_loop()
if loop.is_running():
    loop.create_task(show_app())
else:
    loop.run_until_complete(show_app())

# Store valid signals
# Out:
# Task exception was never retrieved
# future: <Task finished name='Task-4' coro=<show_app() done, defined at C:\Users\pperez\AppData\Local\Temp\1\ipykernel_34904\4241174022.py:113> exception=RuntimeError('This event loop is already running')>
# Traceback (most recent call last):
#   File "C:\Users\pperez\AppData\Local\Temp\1\ipykernel_34904\4241174022.py", line 115, in show_app
#     await server.io_loop.start()
#   File "C:\Users\pperez\AppData\Roaming\Python\Python39\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\pperez\.conda\envs\devbio-napari-cupy\lib\asyncio\base_events.py", line 591, in run_forever
#     self._check_running()
#   File "C:\Users\pperez\.conda\envs\devbio-napari-cupy\lib\asyncio\base_events.py", line 583, in _check_running
#     raise RuntimeError('This event loop is already running')
# RuntimeError: This event loop is already running

# %%
df_cleaned = df_cleaned[valid_signals]

# %%
df_interpolate = df_cleaned.interpolate(method='linear', axis=1)

# %%
df_interpolate

# %%
df_cleaned.to_csv(Path(output_path).as_posix())

# %%
import pandas as pd
import numpy as np
from bokeh.plotting import figure, show, output_notebook
from bokeh.layouts import gridplot
from bokeh.models import ColumnDataSource, HoverTool

# Enable Bokeh output in the notebook
output_notebook()

# Number of plots per row
plots_per_row = 5

# Create a list to hold all the plots
plots = []

for col in df_cleaned.columns:
    # Create a ColumnDataSource for each column
    source = ColumnDataSource(data=dict(index=df_cleaned.index, values=df_interpolate[col]))

    # Create a new plot
    p = figure(title=col, plot_width=275, plot_height=275, tools="hover", tooltips="@index: @values")

    # Add a line renderer with legend and line thickness
    p.line('index', 'values', source=source, line_width=2)
    
    # Add the plot to the list of plots
    plots.append(p)

# Arrange the plots in a grid
grid = gridplot(plots, ncols=plots_per_row)

# Show the results in the notebook
show(grid)

# %%
server.io_loop.stop()

# %%
# Multichannel

import json
import orjson
import glob
from pathlib import Path
import pandas as pd
import numpy as np
import re

# User arguments

pattern = r'mask_tf(\d+)_apoc_cell(\d+)\.json'
port = 5019
input_path = r"H:\PROJECTS-03\Pablo\oscillating\Laurel_project\ppp009"
output_path = r"H:\PROJECTS-03\Pablo\oscillating\Laurel_project\analysis\raw_signals_ppp009_multic"
nan_threshold = 0.8
var_cri = 100
current_socket = 'localhost:8889'
channels = [1, 2]  # List of channels
df = pd.DataFrame()

# Ordering functions

def ordering_function_tf(path):
    match = re.match(pattern, path.name)
    return int(match.group(1))

def ordering_function_cell(path):
    match = re.match(pattern, path.name)
    return int(match.group(2))

def process_subdirectory(subdirectory_path, pattern=pattern, df=df, channels=channels):
    json_files = list(subdirectory_path.glob('mask_tf*_apoc_cell*.json'))
    json_files.sort(key=lambda x: (ordering_function_cell(x), ordering_function_tf(x)))
    cells = {re.match(pattern, file.name).group(2) for file in json_files}

    if cells:
        for cell in cells:
            print(f'Recording cells {subdirectory_path.name}+{cell}')
            json_cell = [json_file for json_file in json_files if f'apoc_cell{cell}' in json_file.stem]
            tfs = [int((re.match(pattern,json_file.name)).group(1)) for json_file in json_cell]
            tfs.sort()
            for (tf, json_file) in zip(tfs, json_cell):
                with json_file.open('rb') as file:
                    data_dict = orjson.loads(file.read())
                    npixels = data_dict.get('npixels')
                    intensities = data_dict.get('intensity')
                    if intensities and len(intensities) > max(channels):
                        for ch in channels:
                            intensity = intensities[ch]
                            column_name = f'{subdirectory_path.name}_{cell}_ch{ch}'
                            df.at[tf, column_name] = intensity / npixels
                    else:
                        for ch in channels:
                            column_name = f'{subdirectory_path.name}_{cell}_ch{ch}'
                            df.at[tf, column_name] = np.nan
    else:
        print(f'No cell metadata in {subdirectory_path.name}')
    
    return df.sort_index()

# Run processing
root_folder = Path(input_path).resolve()
if not root_folder.exists():
    raise FileNotFoundError(f"Root folder does not exist: {root_folder}")

subdirectories = [p.resolve() for p in root_folder.glob('*/') if p.is_dir()]
for subdirectory in subdirectories:
    df = process_subdirectory(subdirectory, df=df)
# Out:
# Recording cells ppp009_xy01+1
# Recording cells ppp009_xy01+0
# Recording cells ppp009_xy02+0
# Recording cells ppp009_xy03+0
# Recording cells ppp009_xy04+0
# Recording cells ppp009_xy05+0
# Recording cells ppp009_xy06+0
# Recording cells ppp009_xy07+0
# Recording cells ppp009_xy08+0
# Recording cells ppp009_xy09+0
# Recording cells ppp009_xy10+2
# Recording cells ppp009_xy10+1
# Recording cells ppp009_xy10+0
# Recording cells ppp009_xy11+1
# Recording cells ppp009_xy11+0
# Recording cells ppp009_xy12+0
# Recording cells ppp009_xy13+1
# Recording cells ppp009_xy13+0
# Recording cells ppp009_xy14+0
# Recording cells ppp009_xy15+2
# Recording cells ppp009_xy15+1
# Recording cells ppp009_xy15+0
# Recording cells ppp009_xy16+1
# Recording cells ppp009_xy16+0
# Recording cells ppp009_xy17+1
# Recording cells ppp009_xy17+0
# Recording cells ppp009_xy18+1
# Recording cells ppp009_xy18+0
# Recording cells ppp009_xy19+2
# Recording cells ppp009_xy19+5
# Recording cells ppp009_xy19+3
# Recording cells ppp009_xy19+1
# Recording cells ppp009_xy19+0
# Recording cells ppp009_xy19+4
# Recording cells ppp009_xy20+2
# Recording cells ppp009_xy20+3
# Recording cells ppp009_xy20+1
# Recording cells ppp009_xy20+0
# Recording cells ppp009_xy20+4
# Recording cells ppp009_xy21+2
# Recording cells ppp009_xy21+1
# Recording cells ppp009_xy21+3
# Recording cells ppp009_xy21+0
# Recording cells ppp009_xy22+2
# Recording cells ppp009_xy22+3
# Recording cells ppp009_xy22+1
# Recording cells ppp009_xy22+0
# Recording cells ppp009_xy22+4
# Recording cells ppp009_xy23+1
# Recording cells ppp009_xy23+0
# Recording cells ppp009_xy24+0
# Recording cells ppp009_xy25+1
# Recording cells ppp009_xy25+0
# Recording cells ppp009_xy26+1
# Recording cells ppp009_xy26+0
# Recording cells ppp009_xy27+1
# Recording cells ppp009_xy27+0
# Recording cells ppp009_xy28+1
# Recording cells ppp009_xy28+0
# Recording cells ppp009_xy29+0
# Recording cells ppp009_xy30+1
# Recording cells ppp009_xy30+0
# Recording cells ppp009_xy31+1
# Recording cells ppp009_xy31+0
# Recording cells ppp009_xy32+1
# Recording cells ppp009_xy32+0
# Recording cells ppp009_xy33+2
# Recording cells ppp009_xy33+6
# Recording cells ppp009_xy33+5
# Recording cells ppp009_xy33+3
# Recording cells ppp009_xy33+1
# Recording cells ppp009_xy33+0
# Recording cells ppp009_xy33+4
# Recording cells ppp009_xy34+2
# Recording cells ppp009_xy34+1
# Recording cells ppp009_xy34+0
# Recording cells ppp009_xy35+1
# Recording cells ppp009_xy35+0
# Recording cells ppp009_xy36+2
# Recording cells ppp009_xy36+1
# Recording cells ppp009_xy36+0
# Recording cells ppp009_xy37+2
# Recording cells ppp009_xy37+1
# Recording cells ppp009_xy37+3
# Recording cells ppp009_xy37+0
# Recording cells ppp009_xy38+1
# Recording cells ppp009_xy38+0
# Recording cells ppp009_xy39+2
# Recording cells ppp009_xy39+1
# Recording cells ppp009_xy39+0
# Recording cells ppp009_xy40+2
# Recording cells ppp009_xy40+1
# Recording cells ppp009_xy40+0
# Recording cells ppp009_xy41+1
# Recording cells ppp009_xy41+0
# Recording cells ppp009_xy42+2
# Recording cells ppp009_xy42+6
# Recording cells ppp009_xy42+5
# Recording cells ppp009_xy42+12
# Recording cells ppp009_xy42+9
# Recording cells ppp009_xy42+11
# Recording cells ppp009_xy42+3
# Recording cells ppp009_xy42+13
# Recording cells ppp009_xy42+14
# Recording cells ppp009_xy42+15
# Recording cells ppp009_xy42+1
# Recording cells ppp009_xy42+0
# Recording cells ppp009_xy42+8
# Recording cells ppp009_xy42+10
# Recording cells ppp009_xy42+7
# Recording cells ppp009_xy42+4
# Recording cells ppp009_xy43+0
# Recording cells ppp009_xy44+1
# Recording cells ppp009_xy44+0
# Recording cells ppp009_xy45+1
# Recording cells ppp009_xy45+0
# Recording cells ppp009_xy46+1
# Recording cells ppp009_xy46+0
# Recording cells ppp009_xy47+1
# Recording cells ppp009_xy47+0
# Recording cells ppp009_xy48+1
# Recording cells ppp009_xy48+0
# Recording cells ppp009_xy49+0
# Recording cells ppp009_xy50+2
# Recording cells ppp009_xy50+1
# Recording cells ppp009_xy50+3
# Recording cells ppp009_xy50+0
# Recording cells ppp009_xy51+2
# Recording cells ppp009_xy51+1
# Recording cells ppp009_xy51+3
# Recording cells ppp009_xy51+0
# Recording cells ppp009_xy52+2
# Recording cells ppp009_xy52+1
# Recording cells ppp009_xy52+0
# Recording cells ppp009_xy53+0
# Recording cells ppp009_xy54+0
# Recording cells ppp009_xy55+1
# Recording cells ppp009_xy55+0
# Recording cells ppp009_xy56+0
# Recording cells ppp009_xy57+0
# Recording cells ppp009_xy58+2
# Recording cells ppp009_xy58+1
# Recording cells ppp009_xy58+3
# Recording cells ppp009_xy58+0
# Recording cells ppp009_xy59+0
# Recording cells ppp009_xy60+1
# Recording cells ppp009_xy60+0
# Recording cells ppp009_xy61+0
# Recording cells ppp009_xy62+2
# Recording cells ppp009_xy62+6
# Recording cells ppp009_xy62+5
# Recording cells ppp009_xy62+9
# Recording cells ppp009_xy62+3
# Recording cells ppp009_xy62+1
# Recording cells ppp009_xy62+0
# Recording cells ppp009_xy62+8
# Recording cells ppp009_xy62+7
# Recording cells ppp009_xy62+4
# Recording cells ppp009_xy63+0
# Recording cells ppp009_xy64+1
# Recording cells ppp009_xy64+0
# Recording cells ppp009_xy65+1
# Recording cells ppp009_xy65+0
# Recording cells ppp009_xy66+2
# Recording cells ppp009_xy66+1
# Recording cells ppp009_xy66+0
# Recording cells ppp009_xy67+2
# Recording cells ppp009_xy67+1
# Recording cells ppp009_xy67+0
# Recording cells ppp009_xy68+0
# Recording cells ppp009_xy69+1
# Recording cells ppp009_xy69+0
# Recording cells ppp009_xy70+2
# Recording cells ppp009_xy70+3
# Recording cells ppp009_xy70+1
# Recording cells ppp009_xy70+0
# Recording cells ppp009_xy70+4
# Recording cells ppp009_xy71+2
# Recording cells ppp009_xy71+1
# Recording cells ppp009_xy71+0
# Recording cells ppp009_xy72+2
# Recording cells ppp009_xy72+1
# Recording cells ppp009_xy72+0
# Recording cells ppp009_xy73+1
# Recording cells ppp009_xy73+0
# Recording cells ppp009_xy74+1
# Recording cells ppp009_xy74+0
# Recording cells ppp009_xy75+0
# Recording cells ppp009_xy76+2
# Recording cells ppp009_xy76+1
# Recording cells ppp009_xy76+0
# Recording cells ppp009_xy77+2
# Recording cells ppp009_xy77+3
# Recording cells ppp009_xy77+1
# Recording cells ppp009_xy77+0
# Recording cells ppp009_xy77+4
# Recording cells ppp009_xy78+0
# Recording cells ppp009_xy79+2
# Recording cells ppp009_xy79+3
# Recording cells ppp009_xy79+1
# Recording cells ppp009_xy79+0
# Recording cells ppp009_xy79+4
# Recording cells ppp009_xy80+1
# Recording cells ppp009_xy80+0
# Recording cells ppp009_xy81+1
# Recording cells ppp009_xy81+0
# Recording cells ppp009_xy82+2
# Recording cells ppp009_xy82+1
# Recording cells ppp009_xy82+3
# Recording cells ppp009_xy82+0
# Recording cells ppp009_xy83+1
# Recording cells ppp009_xy83+0
# Recording cells ppp009_xy84+2
# Recording cells ppp009_xy84+1
# Recording cells ppp009_xy84+0

# %%
df = pd.read_csv('./raw_signals_ppp009_multic', index_col=0)
df_cleaned = pd.read_csv('./raw_signals_ppp009', index_col=0)
base_names = sorted(set(c.rsplit('_ch', 1)[0] for c in df.columns if c.rsplit('_ch', 1)[0] in df_cleaned.columns))
df_ch1 = df[[f"{b}_ch1" for b in base_names if f"{b}_ch1" in df]]
df_ch2 = df[[f"{b}_ch2" for b in base_names if f"{b}_ch2" in df]]
cols_ch1 = sorted(df_ch1.columns)
cols_ch2 = sorted(df_ch2.columns)

# %%
from bokeh.io import output_notebook, show, push_notebook
from bokeh.layouts import column, row
from bokeh.models import Button, ColumnDataSource, CustomJS, LinearAxis, Range1d
from bokeh.plotting import figure, curdoc
from bokeh.application.handlers import FunctionHandler
from bokeh.application import Application
from bokeh.server.server import Server
from tornado.ioloop import IOLoop
import asyncio
from collections import defaultdict


# Assume these two DataFrames are defined:
# df_ch1 = ...
# df_ch2 = ...
# port = 5019
# current_socket = 'localhost:8889'

global valid_signals
selected_plots_source = ColumnDataSource(data=dict(selected_plots=[]))  # Shared global
def modify_doc(doc):

    def get_selected_plots():
        return selected_plots_source.data['selected_plots']

    def create_plots_layout():
        plots, buttons = [], []
        x_vals = list(range(len(df_ch1)))

        # Match channels by base name
        for col1, col2, base_name in zip(cols_ch1, cols_ch2, base_names):
            source_ch1 = ColumnDataSource(data={'x': x_vals, 'y': df_ch1[col1]})
            source_ch2 = ColumnDataSource(data={'x': x_vals, 'y': df_ch2[col2]})

            p = figure(
                        width=300,
                        height=300,
                        title=base_name,
                        x_range=(x_vals[0], x_vals[-1]),
                        y_range= Range1d(start=(df_ch1[col1].min()- 0.05*df_ch1[col1].min()), end=(df_ch1[col1].max()+0.05*df_ch1[col1].max()))
                        )
            p.line('x', 'y', source=source_ch1, line_width=2, color='blue')
            right_range = Range1d(start=(df_ch2[col2].min()- 0.05*df_ch2[col2].min()), end=(df_ch2[col2].max()+0.05*df_ch2[col2].max()))
            p.extra_y_ranges = {"right_axis": right_range}
            p.add_layout(LinearAxis(y_range_name="right_axis"), 'right') 
            p.add_layout(p.yaxis[1], 'right')
            p.line('x', 'y', source=source_ch2, line_width=2, color='red', y_range_name="right_axis")
            plots.append(p)

            # Selection button
#             button = Button(label=base, width=60, button_type="success")

#             def create_button_callback(plot, cols, btn):
#                 def callback():
#                     selected = selected_plots_source.data['selected_plots']
#                     if any(c in selected for c in cols_ch1):
#                         plot.background_fill_color = 'white'
#                         selected = [s for s in selected if s not in cols_ch1]
#                         btn.button_type = 'success'
#                     else:
#                         plot.background_fill_color = 'rgba(255, 0, 0, 0.1)'
#                         selected += cols
#                         btn.button_type = 'danger'
#                     selected_plots_source.data = {'selected_plots': list(set(selected))}
#                     global valid_signals
#                     valid_signals = df_ch1.drop(columns=selected).columns
#                 return callback

#             button.on_click(create_button_callback(p, col1, button))

#             plots.append(p)
#             buttons.append(button)

        layout_rows = []
        for i in range(0, len(plots), 4):
            layout_rows.append(row(*plots[i:i+4]))

        return column(*layout_rows)

    layout = create_plots_layout()

#     print_button = Button(label="Print list of excluded plots", width=200, button_type="primary")
#     print_button.on_click(lambda: print(get_selected_plots()))

    # rerender_button = Button(label="Exclude selected plots", width=200, button_type="warning")
    # def rerender():
    #     print("Re-rendering")
    #     new_layout = create_plots_layout()
    #     doc.clear()
    #     doc.add_root(column(new_layout, print_button, rerender_button))
    # rerender_button.on_click(rerender)

    doc.add_root(layout)


# Attach to Bokeh server
app = Application(FunctionHandler(modify_doc))

server = Server({'/': modify_doc}, port=port, io_loop=IOLoop.current(),
                allow_websocket_origin=[current_socket, f"localhost:{port}"])

async def show_app():
    print(f"Launching Bokeh app on http://localhost:{port}")
    server.io_loop.add_callback(server.show, "/")
    await server.io_loop.start()

loop = asyncio.get_event_loop()
if loop.is_running():
    loop.create_task(show_app())
else:
    loop.run_until_complete(show_app())
# Out:
# Task exception was never retrieved
# future: <Task finished name='Task-4' coro=<show_app() done, defined at C:\Users\pperez\AppData\Local\Temp\1\ipykernel_10740\1213386072.py:102> exception=RuntimeError('This event loop is already running')>
# Traceback (most recent call last):
#   File "C:\Users\pperez\AppData\Local\Temp\1\ipykernel_10740\1213386072.py", line 105, in show_app
#     await server.io_loop.start()
#   File "C:\Users\pperez\AppData\Roaming\Python\Python39\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\pperez\.conda\envs\devbio-napari-cupy\lib\asyncio\base_events.py", line 591, in run_forever
#     self._check_running()
#   File "C:\Users\pperez\.conda\envs\devbio-napari-cupy\lib\asyncio\base_events.py", line 583, in _check_running
#     raise RuntimeError('This event loop is already running')
# RuntimeError: This event loop is already running
# Launching Bokeh app on http://localhost:5019
