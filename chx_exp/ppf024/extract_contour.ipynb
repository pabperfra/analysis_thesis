# %%
import json
import glob
from pathlib import Path, WindowsPath
import pathlib

import pandas as pd
import numpy as np

import numba

import csv
import threading

import re

# %%
pattern = r'mask_tf(\d+)_apoc_cell(\d+)\.json'
df = pd.DataFrame()

# %%
# Ordering functions
def ordering_function_tf(path):
    """Give the timeframe contained in the name of the json file as an integer.
    Use to sort metadata files"""
    
    pattern = r'mask_tf(\d+)_apoc_cell(\d+)\.json'
    match = re.match(pattern, path.name)
    return int(match.group(1))

def ordering_function_cell(path):
    """Give the cell number contained in the name of the json file as an integer.
    Use to sort metadata files"""

    pattern = r'mask_tf(\d+)_apoc_cell(\d+)\.json'
    match = re.match(pattern, path.name)
    return int(match.group(2))

# %%
def process_subdirectory(subdirectory_path, pattern=pattern, dic={}):
    json_files = list(subdirectory_path.glob('mask_tf*_apoc_cell*.json'))
    json_files.sort(key=lambda x: (ordering_function_cell(x), ordering_function_tf(x)))
    cells = {re.match(pattern, file.name).group(2) for file in json_files}  # Cell numbers as in the metadata file names

    # Check whether cells is empty or metadata has been found, if so populate df with average intensity
    if cells:
        for cell in cells:
            print(f'Recording contour of cell {subdirectory.name}_{cell}')
            column_name = subdirectory_path.name + '_' + cell
            json_cell = [json_file for json_file in json_files if 'apoc_cell' + cell in json_file.stem]
            tfs = [int((re.match(pattern, json_file.name)).group(1)) for json_file in json_cell]
            tfs.sort()

            for (tf, json_file) in zip(tfs, json_cell):
                with json_file.open('r') as file:
                    data_dict = json.load(file)
                    dic.setdefault(column_name, {}).setdefault(tf, {
                        'x_coords': data_dict.get('xcoords'),
                        'y_coords': data_dict.get('ycoords')
                    })
    else:
        print(f'No cell metadata in {subdirectory_path.name}')

    return dic

# %%
cells
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 cells
#
# NameError: name 'cells' is not defined

# %%
cd H:/PROJECTS-03/Pablo/oscillating/ppf021_analysis_th_corr/
# Out:
# H:\PROJECTS-03\Pablo\oscillating\ppf021_analysis_th_corr

# %%
root_folder = Path("./raw/metadata/ppf024")
subdirectories = list(root_folder.glob('*/'))

# %%
subdirectories = [subdir for subdir in subdirectories if subdir.is_dir()]

# %%
dic= {}
for subdirectory in subdirectories:
    process_subdirectory(subdirectory, dic=dic)
# Out:
# Recording contour of cell ppf024_xy01_0
# Recording contour of cell ppf024_xy02_0
# Recording contour of cell ppf024_xy02_2
# Recording contour of cell ppf024_xy02_1
# Recording contour of cell ppf024_xy03_0
# Recording contour of cell ppf024_xy04_0
# Recording contour of cell ppf024_xy05_0
# Recording contour of cell ppf024_xy06_0
# Recording contour of cell ppf024_xy06_1
# Recording contour of cell ppf024_xy07_0
# Recording contour of cell ppf024_xy08_0
# Recording contour of cell ppf024_xy08_1
# Recording contour of cell ppf024_xy09_0
# Recording contour of cell ppf024_xy10_0
# Recording contour of cell ppf024_xy11_0
# Recording contour of cell ppf024_xy12_0
# Recording contour of cell ppf024_xy13_0
# Recording contour of cell ppf024_xy14_0
# Recording contour of cell ppf024_xy15_0
# Recording contour of cell ppf024_xy16_0
# Recording contour of cell ppf024_xy17_0
# Recording contour of cell ppf024_xy18_0
# Recording contour of cell ppf024_xy19_0
# Recording contour of cell ppf024_xy20_0
# Recording contour of cell ppf024_xy21_0
# Recording contour of cell ppf024_xy22_0
# Recording contour of cell ppf024_xy22_1
# Recording contour of cell ppf024_xy23_0
# Recording contour of cell ppf024_xy23_1
# Recording contour of cell ppf024_xy24_0
# Recording contour of cell ppf024_xy25_0
# Recording contour of cell ppf024_xy26_0
# Recording contour of cell ppf024_xy27_0
# Recording contour of cell ppf024_xy28_0
# Recording contour of cell ppf024_xy28_2
# Recording contour of cell ppf024_xy28_1
# Recording contour of cell ppf024_xy29_0
# Recording contour of cell ppf024_xy30_0
# Recording contour of cell ppf024_xy31_0
# Recording contour of cell ppf024_xy31_1
# Recording contour of cell ppf024_xy32_0
# Recording contour of cell ppf024_xy33_0
# Recording contour of cell ppf024_xy34_0
# Recording contour of cell ppf024_xy35_0
# Recording contour of cell ppf024_xy36_0
# Recording contour of cell ppf024_xy37_0
# Recording contour of cell ppf024_xy38_0
# Recording contour of cell ppf024_xy39_0
# Recording contour of cell ppf024_xy40_0
# Recording contour of cell ppf024_xy40_1
# Recording contour of cell ppf024_xy41_0
# Recording contour of cell ppf024_xy42_0
# Recording contour of cell ppf024_xy43_0
# Recording contour of cell ppf024_xy44_0
# Recording contour of cell ppf024_xy45_0
# Recording contour of cell ppf024_xy46_0
# Recording contour of cell ppf024_xy47_0
# Recording contour of cell ppf024_xy48_0
# Recording contour of cell ppf024_xy49_0
# Recording contour of cell ppf024_xy50_0
# Recording contour of cell ppf024_xy51_0
# Recording contour of cell ppf024_xy52_0
# Recording contour of cell ppf024_xy53_0
# Recording contour of cell ppf024_xy54_0
# Recording contour of cell ppf024_xy55_0
# Recording contour of cell ppf024_xy56_0
# Recording contour of cell ppf024_xy57_0
# Recording contour of cell ppf024_xy58_0
# Recording contour of cell ppf024_xy59_0
# Recording contour of cell ppf024_xy60_0
# Recording contour of cell ppf024_xy61_0
# Recording contour of cell ppf024_xy62_0
# Recording contour of cell ppf024_xy63_0
# Recording contour of cell ppf024_xy64_0
# Recording contour of cell ppf024_xy65_0
# Recording contour of cell ppf024_xy66_0
# Recording contour of cell ppf024_xy67_0
# Recording contour of cell ppf024_xy67_1
# Recording contour of cell ppf024_xy68_0
# Recording contour of cell ppf024_xy69_0
# Recording contour of cell ppf024_xy69_1
# Recording contour of cell ppf024_xy70_0
# Recording contour of cell ppf024_xy71_0
# Recording contour of cell ppf024_xy72_0
# Recording contour of cell ppf024_xy73_0
# Recording contour of cell ppf024_xy73_1
# Recording contour of cell ppf024_xy74_0
# Recording contour of cell ppf024_xy74_1
# Recording contour of cell ppf024_xy75_0
# Recording contour of cell ppf024_xy76_0
# Recording contour of cell ppf024_xy77_0
# Recording contour of cell ppf024_xy78_0
# Recording contour of cell ppf024_xy79_0
# Recording contour of cell ppf024_xy80_0
# Recording contour of cell ppf024_xy81_0
# Recording contour of cell ppf024_xy82_0
# Recording contour of cell ppf024_xy83_0
# Recording contour of cell ppf024_xy84_0
# Recording contour of cell ppf024_xy85_0
# Recording contour of cell ppf024_xy86_0
# Recording contour of cell ppf024_xy87_0
# Recording contour of cell ppf024_xy88_0
# Recording contour of cell ppf024_xy89_0
# Recording contour of cell ppf024_xy90_0
# Recording contour of cell ppf024_xy91_0
# Recording contour of cell ppf024_xy92_0
# Recording contour of cell ppf024_xy93_0
# Recording contour of cell ppf024_xy93_1
# Recording contour of cell ppf024_xy94_0
# Recording contour of cell ppf024_xy95_0
# Recording contour of cell ppf024_xy96_0
# Recording contour of cell ppf024_xy96_1
# Recording contour of cell ppf024_xy97_0
# Recording contour of cell ppf024_xy98_0
# Recording contour of cell ppf024_xy99_0

# %%
len(dic)
# Out:
# 141

# %%
dic.
# Out:
#   Cell In[12], line 1
#     dic.
#         ^
# SyntaxError: invalid syntax

# %%
# Initialize lists to store data for DataFrame
data = []

# Extract data from the nested dictionary
for column_name, time_data in dic.items():
    #cell_name = column_name.split('_')[-1]
    cell_name = column_name
    
    for tf, coord_data in time_data.items():
        data.append({
            'Cell Name': cell_name,
            'Time Frame': tf,
            'x_coords': coord_data.get('x_coords', []),
            'y_coords': coord_data.get('y_coords', [])
        })

# Create the DataFrame
df = pd.DataFrame(data)

# Optionally, set the time frame as the index
# df.set_index('Time Frame', inplace=True)

# Display the DataFrame
print(df)
# Out:
#           Cell Name  Time Frame  \
# 0     ppf024_xy01_0           0
# 1     ppf024_xy01_0           1
# 2     ppf024_xy01_0           2
# 3     ppf024_xy01_0           3
# 4     ppf024_xy01_0           4
# ...             ...         ...
# 7835  ppf024_xy99_0          70
# 7836  ppf024_xy99_0          71
# 7837  ppf024_xy99_0          72
# 7838  ppf024_xy99_0          73
# 7839  ppf024_xy99_0          74
#
#                                                x_coords  \
# 0     [251.0, 251.5, 252.0, 253.0, 253.5, 254.0, 255...
# 1     [252.0, 253.0, 253.5, 254.0, 255.0, 256.0, 257...
# 2     [246.0, 247.0, 248.0, 249.0, 250.0, 251.0, 252...
# 3     [246.0, 247.0, 247.5, 248.0, 249.0, 249.5, 250...
# 4     [254.0, 255.0, 255.5, 256.0, 257.0, 257.5, 258...
# ...                                                 ...
# 7835  [238.0, 239.0, 239.5, 240.0, 240.5, 241.0, 242...
# 7836  [238.0, 238.5, 239.0, 240.0, 240.5, 241.0, 242...
# 7837  [238.0, 238.5, 239.0, 240.0, 240.5, 241.0, 241...
# 7838  [235.0, 236.0, 237.0, 238.0, 238.5, 239.0, 240...
# 7839  [235.0, 236.0, 237.0, 238.0, 238.5, 239.0, 240...
#
#                                                y_coords
# 0     [224.5, 225.0, 225.5, 225.5, 226.0, 226.5, 226...
# 1     [207.5, 207.5, 208.0, 208.5, 208.5, 208.5, 208...
# 2     [207.5, 207.5, 207.5, 207.5, 207.5, 207.5, 207...
# 3     [200.5, 200.5, 201.0, 201.5, 201.5, 202.0, 202...
# 4     [205.5, 205.5, 206.0, 206.5, 206.5, 206.0, 205...
# ...                                                 ...
# 7835  [155.5, 155.5, 156.0, 156.5, 156.0, 155.5, 155...
# 7836  [155.5, 156.0, 156.5, 156.5, 156.0, 155.5, 155...
# 7837  [155.5, 156.0, 156.5, 156.5, 156.0, 155.5, 156...
# 7838  [156.5, 156.5, 156.5, 156.5, 157.0, 157.5, 157...
# 7839  [155.5, 155.5, 155.5, 155.5, 156.0, 156.5, 156...
#
# [7840 rows x 4 columns]

# %%
df.to_csv('./contour_data_ppf024_median_corr')

# %%
df.iloc[:,0]
# Out:
# Time Frame
# 0     ppf005_xy002_0
# 1     ppf005_xy002_0
# 2     ppf005_xy002_0
# 3     ppf005_xy002_0
# 4     ppf005_xy002_0
#            ...
# 75    ppf005_xy174_0
# 76    ppf005_xy174_0
# 77    ppf005_xy174_0
# 78    ppf005_xy174_0
# 79    ppf005_xy174_0
# Name: Cell Name, Length: 10072, dtype: object

# %%
df
# Out:
#            Cell Name  Time Frame  \
# 0     ppf021_xy001_0           0
# 1     ppf021_xy001_0           1
# 2     ppf021_xy001_0           2
# 3     ppf021_xy001_0           3
# 4     ppf021_xy001_0           4
# ...              ...         ...
# 9911  ppf021_xy110_0          72
# 9912  ppf021_xy110_0          73
# 9913  ppf021_xy110_0          74
# 9914  ppf021_xy110_0          75
# 9915  ppf021_xy110_0          76
#
#                                                x_coords  \
# 0     [274.0, 275.0, 276.0, 277.0, 278.0, 279.0, 280...
# 1     [273.0, 273.5, 274.0, 275.0, 276.0, 277.0, 277...
# 2     [267.0, 268.0, 269.0, 270.0, 271.0, 272.0, 272...
# 3     [270.0, 271.0, 272.0, 273.0, 274.0, 274.5, 275...
# 4     [263.0, 263.5, 264.0, 265.0, 265.5, 266.0, 266...
# ...                                                 ...
# 9911  [177.0, 178.0, 179.0, 180.0, 180.5, 181.0, 182...
# 9912  [175.0, 176.0, 177.0, 178.0, 179.0, 180.0, 181...
# 9913  [176.0, 177.0, 178.0, 179.0, 180.0, 181.0, 181...
# 9914  [178.0, 179.0, 179.5, 180.0, 181.0, 182.0, 183...
# 9915  [174.0, 175.0, 176.0, 177.0, 178.0, 179.0, 180...
#
#                                                y_coords
# 0     [220.5, 220.5, 220.5, 220.5, 220.5, 220.5, 220...
# 1     [222.5, 223.0, 223.5, 223.5, 223.5, 223.5, 223...
# 2     [221.5, 221.5, 221.5, 221.5, 221.5, 221.5, 222...
# 3     [226.5, 226.5, 226.5, 226.5, 226.5, 227.0, 227...
# 4     [219.5, 220.0, 220.5, 220.5, 220.0, 219.5, 220...
# ...                                                 ...
# 9911  [78.5, 78.5, 78.5, 78.5, 79.0, 79.5, 79.5, 79....
# 9912  [79.5, 79.5, 79.5, 79.5, 79.5, 79.5, 79.5, 79....
# 9913  [79.5, 79.5, 79.5, 79.5, 79.5, 79.5, 80.0, 80....
# 9914  [78.5, 78.5, 79.0, 79.5, 79.5, 79.5, 79.5, 79....
# 9915  [80.5, 80.5, 80.5, 80.5, 80.5, 80.5, 80.5, 80....
#
# [9916 rows x 4 columns]

# %%
df.loc[df['Cell Name']=='ppf005_xy003_0', 'x_coords']
# Out:
# Time Frame
# 0     [265.0, 266.0, 267.0, 268.0, 269.0, 270.0, 271...
# 1     [263.0, 264.0, 265.0, 265.5, 266.0, 267.0, 267...
# 2     [263.0, 264.0, 265.0, 266.0, 267.0, 268.0, 268...
# 3     [263.0, 264.0, 265.0, 266.0, 266.5, 267.0, 268...
# 4     [262.0, 263.0, 264.0, 265.0, 266.0, 267.0, 267...
#                             ...
# 75    [262.0, 263.0, 264.0, 265.0, 266.0, 267.0, 268...
# 76    [261.0, 262.0, 262.5, 263.0, 264.0, 264.5, 265...
# 77    [260.0, 260.5, 261.0, 261.5, 262.0, 263.0, 264...
# 78    [259.0, 260.0, 260.5, 261.0, 261.5, 262.0, 263...
# 79    [259.0, 259.5, 260.0, 260.5, 261.0, 262.0, 263...
# Name: x_coords, Length: 80, dtype: object

# %%
## Contour extraction with multithread
def multi_threaded_file_reader(file_paths):
    threads = []
    results = {}

    # Define the worker function
    def read_file_thread(file_path):
        result = read_file(file_path)
        results[file_path] = result

    # Create and start threads
    for file_path in file_paths:
        thread = threading.Thread(target=read_file_thread, args=(file_path,))
        threads.append(thread)
        thread.start()

    # Wait for all threads to finish
    for thread in threads:
        thread.join()

    return results

# %%
subdirectories_paths = list(map(lambda path: path.as_posix(), subdirectories))

# %%
dic= {}
for subdirectory in subdirectories:
    process_subdirectory(subdirectory, dic=dic)

# %%
import concurrent.futures

def process_subdirectory(subdirectory_path, pattern=pattern, dic={}):
    json_files = list(subdirectory_path.glob('mask_tf*_apoc_cell*.json'))
    json_files.sort(key=lambda x: (ordering_function_cell(x), ordering_function_tf(x)))
    cells = {re.match(pattern, file.name).group(2) for file in json_files}  # Cell numbers as in the metadata file names

    # Check whether cells is empty or metadata has been found, if so populate df with average intensity
    if cells:
        with concurrent.futures.ThreadPoolExecutor() as executor:
            futures = []

            for cell in cells:
                print(f'Submitting task for cell {subdirectory_path.name}_{cell}')
                column_name = subdirectory_path.name + '_' + cell
                json_cell = [json_file for json_file in json_files if 'apoc_cell' + cell in json_file.stem]
                tfs = [int((re.match(pattern, json_file.name)).group(1)) for json_file in json_cell]
                tfs.sort()

                for (tf, json_file) in zip(tfs, json_cell):
                    futures.append(executor.submit(process_json_file, tf, json_file, column_name, dic))

            # Wait for all tasks to complete
            concurrent.futures.wait(futures)

    else:
        print(f'No cell metadata in {subdirectory_path.name}')

    return dic

def process_json_file(tf, json_file, column_name, dic):
    with json_file.open('r') as file:
        data_dict = json.load(file)
        dic.setdefault(column_name, {}).setdefault(tf, {
            'x_coords': data_dict.get('xcoords'),
            'y_coords': data_dict.get('ycoords')
        })

if __name__ == "__main__":
    # Example usage:
    import pathlib

    subdirectories = [pathlib.Path("subdir1"), pathlib.Path("subdir2")]
    for subdirectory in subdirectories:
        process_subdirectory(subdirectory)
